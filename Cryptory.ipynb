# %%
from cryptory import Cryptory

# %%
my_cryptory=Cryptory(from_date='2017-07-01')

# %%
import pandas as pd
my_cap=my_cryptory.extract_coinmarketcap("bitcoin")
#select volume from market cap
volume_market_cap=my_cap[['volume']]
volume_market_cap=volume_market_cap.rename(columns={'volume':'volume_market_cap'})
#rename the column

# %%
bitcoin_google_trends=my_cryptory.get_google_trends(kw_list=['bitcoin'])

# %%
bitcoin_google_trends=bitcoin_google_trends.rename(columns={'bitcoin':'bitcoin_google_trends'})

# %%
#get dow james
bitcoin_stock_price=my_cryptory.get_stock_prices(market="%5EDJI")

# %%
#select volume, close from dow james stock price
bitcoin_stock_price=bitcoin_stock_price.loc[:,['close','volume']]
bitcoin_stock_price=bitcoin_stock_price.rename(columns={'close':'bitcoin_stock_price_close','volume':'bitcoin_stock_price_volume'})

# %%
bitcoin_stock_price
# Out:
#      bitcoin_stock_price_close  bitcoin_stock_price_volume
# 0                 25451.060547                 329680000.0
# 1                 25451.060547                 329680000.0
# 2                 25527.070312                 297530000.0
# 3                 25414.099609                 273670000.0
# 4                 25241.939453                 274940000.0
# 5                 25044.289062                 228820000.0
# 6                 25058.119141                 274080000.0
# 7                 25058.119141                 274080000.0
# 8                 25058.119141                 274080000.0
# 9                 25064.500000                 285760000.0
# 10                25199.289062                 252870000.0
# 11                25119.890625                 250450000.0
# 12                25064.359375                 231270000.0
# 13                25019.410156                 255520000.0
# 14                25019.410156                 255520000.0
# ...

# %%
oil_prices=my_cryptory.get_oil_prices()
oil_prices
# Out:
#           date  oil_price
# 0   2018-07-28      67.90
# 1   2018-07-27      67.90
# 2   2018-07-26      67.90
# 3   2018-07-25      67.90
# 4   2018-07-24      67.90
# 5   2018-07-23      67.90
# 6   2018-07-22      70.31
# 7   2018-07-21      70.31
# 8   2018-07-20      70.31
# 9   2018-07-19      69.42
# 10  2018-07-18      68.78
# 11  2018-07-17      68.03
# 12  2018-07-16      68.22
# 13  2018-07-15      71.03
# 14  2018-07-14      71.03
# 15  2018-07-13      71.03
# 16  2018-07-12      70.28
# 17  2018-07-11      70.47
# 18  2018-07-10      74.11
# 19  2018-07-09      73.93
# 20  2018-07-08      73.78
# 21  2018-07-07      73.78
# 22  2018-07-06      73.78
# 23  2018-07-05      73.05
# 24  2018-07-04      74.19
# 25  2018-07-03      74.19
# 26  2018-07-02      73.89
# 27  2018-07-01      74.13
# 28  2018-06-30      74.13
# 29  2018-06-29      74.13
# ..         ...        ...
# 363 2017-07-30      49.72
# 364 2017-07-29      49.72
# 365 2017-07-28      49.72
# ...

# %%
my_cryptory.get_exchange_rates(from_currency="USD",to_currency="EUR")
# Out:
#           date  exch_rate
# 0   2018-07-28     1.1625
# 1   2018-07-27     1.1625
# 2   2018-07-26     1.1716
# 3   2018-07-25     1.1690
# 4   2018-07-24     1.1706
# 5   2018-07-23     1.1716
# 6   2018-07-22     1.1670
# 7   2018-07-21     1.1670
# 8   2018-07-20     1.1670
# 9   2018-07-19     1.1588
# 10  2018-07-18     1.1611
# 11  2018-07-17     1.1707
# 12  2018-07-16     1.1720
# 13  2018-07-15     1.1643
# 14  2018-07-14     1.1643
# 15  2018-07-13     1.1643
# 16  2018-07-12     1.1658
# 17  2018-07-11     1.1735
# 18  2018-07-10     1.1713
# 19  2018-07-09     1.1789
# 20  2018-07-08     1.1724
# 21  2018-07-07     1.1724
# 22  2018-07-06     1.1724
# 23  2018-07-05     1.1709
# 24  2018-07-04     1.1665
# 25  2018-07-03     1.1665
# 26  2018-07-02     1.1639
# 27  2018-07-01     1.1658
# 28  2018-06-30     1.1658
# 29  2018-06-29     1.1658
# ..         ...        ...
# 363 2017-07-30     1.1729
# 364 2017-07-29     1.1729
# 365 2017-07-28     1.1729
# ...

# %%
my_cryptory.extract_poloniex(coin1="btc",coin2="eth")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-18-90d5dd253cb4> in <module>()
# ----> 1 my_cryptory.extract_poloniex(coin1="btc",coin2="eth")
#
# ~\Anaconda3\lib\site-packages\cryptory\cryptory.py in extract_poloniex(self, coin1, coin2, coin1_col, coin2_col)
#     227                 coin1.upper(), coin2.upper(), from_date, to_date)
#     228         try:
# --> 229             parsed_page = urlopen(url, timeout=self.timeout).read()
#     230             parsed_page = parsed_page.decode("utf8")
#     231         except:
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
# ...

# %%
df=pd.DataFrame(data=dic)

# %%
exc=my_cryptory.get_exchange_rates(from_currency="USD", to_currency="EUR")
exc.iloc[0:937,1:]
dic={'btc':gd,'exch_rate':exc}
dic
